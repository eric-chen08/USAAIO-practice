# %% [markdown]
# # latex practice

# %% [markdown]
# $\|x\|$

# %% [markdown]
# $$A = \begin{bmatrix} 1 & 2 \\
#                       3 & 4 \\
#                       5 & 6
#       \end{bmatrix} $$

# %% [markdown]
# $$
# x^\top = \begin{bmatrix} x_1 & x_2 & x_3 \end{bmatrix}
# $$

# %% [markdown]
# $x^T$

# %% [markdown]
# $I_n$

# %% [markdown]
# $\langle x, y \rangle
# $

# %% [markdown]
# $$
# \mathrm{proj}_v(x) = \frac{v^\top x}{v^\top v}v
# $$

# %% [markdown]
# $\hat e$

# %% [markdown]
# $\kappa_{ij}$

# %% [markdown]
# $\mathbb{R}^d
# $

# %% [markdown]
# $A \in \mathbb{R}^{N \times d}$

# %% [markdown]
# $$\sum_{i=0}^{n} f(x) $$

# %% [markdown]
# $$\prod_{i=0}^{n}f(x)$$

# %% [markdown]
# $$\nabla_\theta
# $$
# $\nabla$

# %% [markdown]
# $\Phi = U\Sigma V^\top$
